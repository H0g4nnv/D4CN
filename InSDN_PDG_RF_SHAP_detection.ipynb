# %% [markdown]
# # Import

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.41.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.65.0)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.1)
# Collecting slicer==0.0.7 (from shap)
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.56.4)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->shap) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7

# %%
import shap
import pandas as pd
import seaborn as sns

# Evaluation metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import auc, roc_curve, roc_auc_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
def evaluation(y_test, y_pred):
  print('Misclassified samples: %d' % (y_test != y_pred).sum())
  result = confusion_matrix(y_test, y_pred)
  print("Confusion Matrix:")
  print(result)
  sns.heatmap(result, annot=True)
  result1 = classification_report(y_test, y_pred)
  print("Classification Report:",)
  print (result1)
  result2 = 100* accuracy_score(y_test, y_pred)
  print("Accuracy:", result2)
  result3 = precision_score(y_test, y_pred, average='macro')
  print("Precision:",result3)
  result4 = recall_score(y_test, y_pred, average='macro')
  print("Recall:",result4)
  result5 = f1_score(y_test, y_pred, average='macro')
  print("F1:",result5)
  #result6 = roc_auc_score(y_test, y_pred, multi_class='ovo')
  #print("AUC:",result6)

# %% [markdown]
# # Load adv samples

# %%
feature_list = ['Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts', 'TotLen Fwd Pkts',
       'TotLen Bwd Pkts', 'Fwd Pkt Len Max', 'Fwd Pkt Len Min',
       'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Bwd Pkt Len Max',
       'Bwd Pkt Len Min', 'Bwd Pkt Len Mean', 'Bwd Pkt Len Std', 'Flow Byts/s',
       'Flow Pkts/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max',
       'Flow IAT Min', 'Fwd IAT Tot', 'Fwd IAT Mean', 'Fwd IAT Std',
       'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Tot', 'Bwd IAT Mean',
       'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags',
       'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Len',
       'Bwd Header Len', 'Fwd Pkts/s', 'Bwd Pkts/s', 'Pkt Len Min',
       'Pkt Len Max', 'Pkt Len Mean', 'Pkt Len Std', 'Pkt Len Var',
       'FIN Flag Cnt', 'SYN Flag Cnt', 'RST Flag Cnt', 'PSH Flag Cnt',
       'ACK Flag Cnt', 'URG Flag Cnt', 'CWE Flag Count', 'ECE Flag Cnt',
       'Down/Up Ratio', 'Pkt Size Avg', 'Fwd Seg Size Avg', 'Bwd Seg Size Avg',
       'Fwd Byts/b Avg', 'Fwd Pkts/b Avg', 'Fwd Blk Rate Avg',
       'Bwd Byts/b Avg', 'Bwd Pkts/b Avg', 'Bwd Blk Rate Avg',
       'Subflow Fwd Pkts', 'Subflow Fwd Byts', 'Subflow Bwd Pkts',
       'Subflow Bwd Byts', 'Init Fwd Win Byts', 'Init Bwd Win Byts',
       'Fwd Act Data Pkts', 'Fwd Seg Size Min', 'Active Mean', 'Active Std',
       'Active Max', 'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max',
       'Idle Min']

# %%
#hsj_path = '/content/drive/MyDrive/DACN_XAI_Adv_defense/Dataset/insdn/adv/hsj/adv_hsj_target.csv'
#hsj_label_path = '/content/drive/MyDrive/DACN_XAI_Adv_defense/Dataset/insdn/adv/hsj/label_hsj_target.csv'

pdg_path = '/content/drive/MyDrive/Dataset/insdn/adv/pgd/adv_pgd_multi_target.csv'

# %%
pdg_df = pd.read_csv(pdg_path)

# %%
pdg_df.columns = feature_list
pdg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77203 entries, 0 to 77202
# Data columns (total 76 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Flow Duration      77203 non-null  float64
#  1   Tot Fwd Pkts       77203 non-null  float64
#  2   Tot Bwd Pkts       77203 non-null  float64
#  3   TotLen Fwd Pkts    77203 non-null  float64
#  4   TotLen Bwd Pkts    77203 non-null  float64
#  5   Fwd Pkt Len Max    77203 non-null  float64
#  6   Fwd Pkt Len Min    77203 non-null  float64
#  7   Fwd Pkt Len Mean   77203 non-null  float64
#  8   Fwd Pkt Len Std    77203 non-null  float64
#  9   Bwd Pkt Len Max    77203 non-null  float64
#  10  Bwd Pkt Len Min    77203 non-null  float64
#  11  Bwd Pkt Len Mean   77203 non-null  float64
#  12  Bwd Pkt Len Std    77203 non-null  float64
#  13  Flow Byts/s        77203 non-null  float64
#  14  Flow Pkts/s        77203 non-null  float64
#  15  Flow IAT Mean      77203 non-null  float64
#  16  Flow IAT Std       77203 non-null  float64
#  17  Flow IAT Max       77203 non-null  float64
#  18  Flow IAT Min       77203 non-null  float64
#  19  Fwd IAT Tot        77203 non-null  float64
#  20  Fwd IAT Mean       77203 non-null  float64
#  21  Fwd IAT Std        77203 non-null  float64
#  22  Fwd IAT Max        77203 non-null  float64
#  23  Fwd IAT Min        77203 non-null  float64
#  24  Bwd IAT Tot        77203 non-null  float64
#  25  Bwd IAT Mean       77203 non-null  float64
#  26  Bwd IAT Std        77203 non-null  float64
#  27  Bwd IAT Max        77203 non-null  float64
#  28  Bwd IAT Min        77203 non-null  float64
#  29  Fwd PSH Flags      77203 non-null  float64
#  30  Bwd PSH Flags      77203 non-null  float64
#  31  Fwd URG Flags      77203 non-null  float64
#  32  Bwd URG Flags      77203 non-null  float64
#  33  Fwd Header Len     77203 non-null  float64
#  34  Bwd Header Len     77203 non-null  float64
#  35  Fwd Pkts/s         77203 non-null  float64
#  36  Bwd Pkts/s         77203 non-null  float64
#  37  Pkt Len Min        77203 non-null  float64
#  38  Pkt Len Max        77203 non-null  float64
#  39  Pkt Len Mean       77203 non-null  float64
#  40  Pkt Len Std        77203 non-null  float64
#  41  Pkt Len Var        77203 non-null  float64
#  42  FIN Flag Cnt       77203 non-null  float64
#  43  SYN Flag Cnt       77203 non-null  float64
#  44  RST Flag Cnt       77203 non-null  float64
#  45  PSH Flag Cnt       77203 non-null  float64
#  46  ACK Flag Cnt       77203 non-null  float64
#  47  URG Flag Cnt       77203 non-null  float64
#  48  CWE Flag Count     77203 non-null  float64
#  49  ECE Flag Cnt       77203 non-null  float64
#  50  Down/Up Ratio      77203 non-null  float64
#  51  Pkt Size Avg       77203 non-null  float64
#  52  Fwd Seg Size Avg   77203 non-null  float64
#  53  Bwd Seg Size Avg   77203 non-null  float64
#  54  Fwd Byts/b Avg     77203 non-null  float64
#  55  Fwd Pkts/b Avg     77203 non-null  float64
#  56  Fwd Blk Rate Avg   77203 non-null  float64
#  57  Bwd Byts/b Avg     77203 non-null  float64
#  58  Bwd Pkts/b Avg     77203 non-null  float64
#  59  Bwd Blk Rate Avg   77203 non-null  float64
#  60  Subflow Fwd Pkts   77203 non-null  float64
#  61  Subflow Fwd Byts   77203 non-null  float64
#  62  Subflow Bwd Pkts   77203 non-null  float64
#  63  Subflow Bwd Byts   77203 non-null  float64
#  64  Init Fwd Win Byts  77203 non-null  float64
#  65  Init Bwd Win Byts  77203 non-null  float64
#  66  Fwd Act Data Pkts  77203 non-null  float64
#  67  Fwd Seg Size Min   77203 non-null  float64
#  68  Active Mean        77203 non-null  float64
#  69  Active Std         77203 non-null  float64
#  70  Active Max         77203 non-null  float64
#  71  Active Min         77203 non-null  float64
#  72  Idle Mean          77203 non-null  float64
#  73  Idle Std           77203 non-null  float64
#  74  Idle Max           77203 non-null  float64
#  75  Idle Min           77203 non-null  float64
# dtypes: float64(76)
# memory usage: 44.8 MB

# %%
#hsj_label = pd.read_csv(hsj_label_path)
#hsj_label.info()

# %% [markdown]
# # Load ML-based IDS model

# %%
import joblib
# load
model = joblib.load("/content/drive/MyDrive/InSDN/random_forest_smote.joblib")

# %%
y_pred = model.predict(pdg_df)

# %%
print(type(y_pred))
# Out:
# <class 'numpy.ndarray'>

# %%
y_pred.shape
# Out:
# (77203,)

# %%
evaluation(hsj_label.values, y_pred)

# %% [markdown]
# Correctly classified:
#
# Class 1: 1
#
# Class 2: 2
#
# CLass 3: 134

# %% [markdown]
# # SHAP

# %%
explainer = shap.Explainer(model)

# %%
shap_values = explainer(pdg_df)

# %%
exp = shap.Explanation(shap_values[:,:,0], shap_values.base_values[:,0], pdg_df, feature_names=feature_list)

# %%
idx = 10

# %%
# Create a DataFrame with the SHAP values and feature names
df_shap_values = pd.DataFrame({'SHAP Values': exp[idx].values}, index=feature_list)
df_shap_values.sort_values(by=['SHAP Values'], ascending=False, inplace=True)
first_column = df_shap_values.iloc[:, 0][:10].tolist()

# %%
df_shap_values.head()
# Out:
#                  SHAP Values
# Bwd Pkt Len Min     0.057067
# Pkt Size Avg        0.048740
# Pkt Len Std         0.046510
# Pkt Len Max         0.039290
# Pkt Len Mean        0.029734

# %%
# Get the index as a list
index_list = df_shap_values.index[:10].tolist()

print(index_list)
# Out:
# ['Bwd Pkt Len Min', 'Pkt Size Avg', 'Pkt Len Std', 'Pkt Len Max', 'Pkt Len Mean', 'Fwd Pkt Len Max', 'Bwd Seg Size Avg', 'Tot Fwd Pkts', 'Fwd Pkt Len Min', 'Bwd Pkt Len Max']

# %%
print(first_column)
# Out:
# [0.05706701142298282, 0.04873950585721053, 0.04651002555322309, 0.03929020526232883, 0.02973408106443929, 0.029302056868340202, 0.02497160165415166, 0.020394554424479308, 0.019122605435318216, 0.01846951442523516]

# %%
print(exp[idx].values)
# Out:
# [ 1.67355083e-03  2.03945544e-02  1.27033216e-02 -2.73430893e-03
#   9.80436001e-03  2.93020569e-02  1.91226054e-02  1.46393626e-02
#   1.43878222e-02  1.84695144e-02  5.70670114e-02  1.71295009e-02
#  -9.89180184e-04  4.23825083e-03 -3.55544035e-03 -1.49570825e-03
#   4.67582078e-03  1.05118737e-03  2.80018986e-03  1.43786645e-03
#   9.72259643e-04  4.52134676e-03 -1.21261037e-03  1.06704877e-03
#  -6.73382299e-03 -3.53883897e-03 -4.04136414e-03  1.67094019e-03
#   1.62908335e-03  0.00000000e+00  7.26948001e-03  0.00000000e+00
#   3.18155134e-04 -1.32733115e-02 -3.14612395e-02 -3.38562600e-04
#  -1.08161732e-03  1.40666135e-02  3.92902053e-02  2.97340811e-02
#   4.65100256e-02 -1.91906488e-03  4.77229346e-03  1.24525590e-02
#   2.04929492e-04  6.58607646e-03  1.80213667e-02  6.23927664e-04
#   0.00000000e+00  0.00000000e+00  1.19979818e-02  4.87395059e-02
#   1.44892357e-02  2.49716017e-02  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   6.89369594e-04  5.63993176e-04  5.35112532e-03  1.00330547e-02
#  -4.75505806e-03 -1.34163221e-02  2.00603297e-03  0.00000000e+00
#   3.61438036e-03 -1.51464301e-03 -1.10439365e-04 -3.40639624e-07
#  -1.58675342e-04  1.43308408e-03  7.60159966e-04  9.38255326e-04]

# %%
shap.plots.waterfall(exp[idx], max_display=20)

# %%
explainer.expected_value.shape
# Out:
# (8,)

# %%
print(explainer.expected_value)
# Out:
# [0.1981354  0.28483611 0.35395455 0.15458753 0.00407478 0.00155968
#  0.0015264  0.00132556]

# %%
shap_values.shape
# Out:
# (77203, 76, 8)

# %%
shap_values.values.shape
# Out:
# (77203, 76, 8)

# %%
shap_values.base_values.shape
# Out:
# (77203, 8)

# %% [markdown]
# # Extract local feature for each adv sample (50000 in total)

# %%
for idx in range(0, 50000):
  # Create a DataFrame with the SHAP values and feature names
  df_shap_values = pd.DataFrame({'SHAP Values': exp[idx].values}, index=feature_list)
  df_shap_values.sort_values(by=['SHAP Values'], ascending=False, inplace=True)
  df_shap_values.to_csv('/content/drive/MyDrive/DACN_XAI_Adv_defense/InSDN/Result/SHAP_ADVSamples_' + str(idx) + '.csv')
  print('Extracted local importance feature of the ' + str(idx) + 'adv sample.')

# %% [markdown]
# # Detection phase

# %%
import os
import pandas as pd

# %%
whitelist_df = pd.read_csv('/content/drive/MyDrive/InSDN/top24_InSDN.csv')
whitelist_df.head(24)
# Out:
#               Feature  Frequency
# 0      Bwd Header Len      60910
# 1        Pkt Size Avg      48472
# 2         Pkt Len Max      48112
# 3      Fwd Header Len      47441
# 4         Pkt Len Std      46926
# 5        Pkt Len Mean      42886
# 6     Bwd Pkt Len Min      39930
# 7         Pkt Len Min      38137
# 8    Bwd Seg Size Avg      37411
# 9       Down/Up Ratio      36935
# 10  Init Bwd Win Byts      34754
# 11   Fwd Seg Size Avg      28154
# 12         Bwd Pkts/s      27404
# 13   Subflow Bwd Pkts      27267
# 14        Flow Pkts/s      24526
# 15   Subflow Fwd Pkts      22413
# 16       Tot Fwd Pkts      22331
# 17       SYN Flag Cnt      16891
# 18       FIN Flag Cnt      15927
# 19       ACK Flag Cnt      15463
# 20    Bwd Pkt Len Max      14931
# 21    Fwd Pkt Len Max      14387
# 22       Tot Bwd Pkts      13000
# 23    Fwd Pkt Len Min      10501

# %% [markdown]
# ##Detection rate (top 24) = 38594/50000

# %%
whitelist = whitelist_df.iloc[:, 0][:24].tolist()
print(whitelist)
# Out:
# ['Bwd Header Len', 'Pkt Size Avg', 'Pkt Len Max', 'Fwd Header Len', 'Pkt Len Std', 'Pkt Len Mean', 'Bwd Pkt Len Min', 'Pkt Len Min', 'Bwd Seg Size Avg', 'Down/Up Ratio', 'Init Bwd Win Byts', 'Fwd Seg Size Avg', 'Bwd Pkts/s', 'Subflow Bwd Pkts', 'Flow Pkts/s', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'SYN Flag Cnt', 'FIN Flag Cnt', 'ACK Flag Cnt', 'Bwd Pkt Len Max', 'Fwd Pkt Len Max', 'Tot Bwd Pkts', 'Fwd Pkt Len Min']

# %%
# Create an empty dictionary to store the data
data_dict = {}

for idx in range(0, 50000):
  # Create a DataFrame with the SHAP values and feature names
  df_shap_values = pd.DataFrame({'SHAP Values': exp[idx].values}, index=feature_list)
  df_shap_values.sort_values(by=['SHAP Values'], ascending=False, inplace=True)
  index_list = df_shap_values.index[:10].tolist()

  # Add the list to the dictionary with the file name as the key
  data_dict['SHAP_ADVSamples_' + str(idx)] = index_list
  print('Extracted local importance feature of the ' + str(idx) + ' adv sample into dict.')
# Out:
# Streaming output truncated to the last 5000 lines.
# Extracted local importance feature of the 45000 adv sample into dict.
# Extracted local importance feature of the 45001 adv sample into dict.
# Extracted local importance feature of the 45002 adv sample into dict.
# Extracted local importance feature of the 45003 adv sample into dict.
# Extracted local importance feature of the 45004 adv sample into dict.
# Extracted local importance feature of the 45005 adv sample into dict.
# Extracted local importance feature of the 45006 adv sample into dict.
# Extracted local importance feature of the 45007 adv sample into dict.
# Extracted local importance feature of the 45008 adv sample into dict.
# Extracted local importance feature of the 45009 adv sample into dict.
# Extracted local importance feature of the 45010 adv sample into dict.
# Extracted local importance feature of the 45011 adv sample into dict.
# Extracted local importance feature of the 45012 adv sample into dict.
# Extracted local importance feature of the 45013 adv sample into dict.
# Extracted local importance feature of the 45014 adv sample into dict.
# Extracted local importance feature of the 45015 adv sample into dict.
# Extracted local importance feature of the 45016 adv sample into dict.
# Extracted local importance feature of the 45017 adv sample into dict.
# Extracted local importance feature of the 45018 adv sample into dict.
# Extracted local importance feature of the 45019 adv sample into dict.
# Extracted local importance feature of the 45020 adv sample into dict.
# Extracted local importance feature of the 45021 adv sample into dict.
# Extracted local importance feature of the 45022 adv sample into dict.
# Extracted local importance feature of the 45023 adv sample into dict.
# Extracted local importance feature of the 45024 adv sample into dict.
# Extracted local importance feature of the 45025 adv sample into dict.
# Extracted local importance feature of the 45026 adv sample into dict.
# Extracted local importance feature of the 45027 adv sample into dict.
# Extracted local importance feature of the 45028 adv sample into dict.
# Extracted local importance feature of the 45029 adv sample into dict.
# Extracted local importance feature of the 45030 adv sample into dict.
# Extracted local importance feature of the 45031 adv sample into dict.
# Extracted local importance feature of the 45032 adv sample into dict.
# Extracted local importance feature of the 45033 adv sample into dict.
# Extracted local importance feature of the 45034 adv sample into dict.
# Extracted local importance feature of the 45035 adv sample into dict.
# Extracted local importance feature of the 45036 adv sample into dict.
# Extracted local importance feature of the 45037 adv sample into dict.
# Extracted local importance feature of the 45038 adv sample into dict.
# Extracted local importance feature of the 45039 adv sample into dict.
# Extracted local importance feature of the 45040 adv sample into dict.
# Extracted local importance feature of the 45041 adv sample into dict.
# Extracted local importance feature of the 45042 adv sample into dict.
# Extracted local importance feature of the 45043 adv sample into dict.
# Extracted local importance feature of the 45044 adv sample into dict.
# Extracted local importance feature of the 45045 adv sample into dict.
# Extracted local importance feature of the 45046 adv sample into dict.
# Extracted local importance feature of the 45047 adv sample into dict.
# Extracted local importance feature of the 45048 adv sample into dict.
# Extracted local importance feature of the 45049 adv sample into dict.
# Extracted local importance feature of the 45050 adv sample into dict.
# Extracted local importance feature of the 45051 adv sample into dict.
# Extracted local importance feature of the 45052 adv sample into dict.
# Extracted local importance feature of the 45053 adv sample into dict.
# Extracted local importance feature of the 45054 adv sample into dict.
# Extracted local importance feature of the 45055 adv sample into dict.
# Extracted local importance feature of the 45056 adv sample into dict.
# Extracted local importance feature of the 45057 adv sample into dict.
# Extracted local importance feature of the 45058 adv sample into dict.
# Extracted local importance feature of the 45059 adv sample into dict.
# Extracted local importance feature of the 45060 adv sample into dict.
# Extracted local importance feature of the 45061 adv sample into dict.
# Extracted local importance feature of the 45062 adv sample into dict.
# Extracted local importance feature of the 45063 adv sample into dict.
# Extracted local importance feature of the 45064 adv sample into dict.
# Extracted local importance feature of the 45065 adv sample into dict.
# Extracted local importance feature of the 45066 adv sample into dict.
# Extracted local importance feature of the 45067 adv sample into dict.
# Extracted local importance feature of the 45068 adv sample into dict.
# Extracted local importance feature of the 45069 adv sample into dict.
# Extracted local importance feature of the 45070 adv sample into dict.
# Extracted local importance feature of the 45071 adv sample into dict.
# Extracted local importance feature of the 45072 adv sample into dict.
# Extracted local importance feature of the 45073 adv sample into dict.
# Extracted local importance feature of the 45074 adv sample into dict.
# Extracted local importance feature of the 45075 adv sample into dict.
# Extracted local importance feature of the 45076 adv sample into dict.
# Extracted local importance feature of the 45077 adv sample into dict.
# Extracted local importance feature of the 45078 adv sample into dict.
# Extracted local importance feature of the 45079 adv sample into dict.
# Extracted local importance feature of the 45080 adv sample into dict.
# Extracted local importance feature of the 45081 adv sample into dict.
# Extracted local importance feature of the 45082 adv sample into dict.
# Extracted local importance feature of the 45083 adv sample into dict.
# Extracted local importance feature of the 45084 adv sample into dict.
# Extracted local importance feature of the 45085 adv sample into dict.
# Extracted local importance feature of the 45086 adv sample into dict.
# Extracted local importance feature of the 45087 adv sample into dict.
# Extracted local importance feature of the 45088 adv sample into dict.
# Extracted local importance feature of the 45089 adv sample into dict.
# Extracted local importance feature of the 45090 adv sample into dict.
# Extracted local importance feature of the 45091 adv sample into dict.
# Extracted local importance feature of the 45092 adv sample into dict.
# Extracted local importance feature of the 45093 adv sample into dict.
# Extracted local importance feature of the 45094 adv sample into dict.
# Extracted local importance feature of the 45095 adv sample into dict.
# Extracted local importance feature of the 45096 adv sample into dict.
# Extracted local importance feature of the 45097 adv sample into dict.
# Extracted local importance feature of the 45098 adv sample into dict.
# Extracted local importance feature of the 45099 adv sample into dict.
# Extracted local importance feature of the 45100 adv sample into dict.
# Extracted local importance feature of the 45101 adv sample into dict.
# Extracted local importance feature of the 45102 adv sample into dict.
# Extracted local importance feature of the 45103 adv sample into dict.
# Extracted local importance feature of the 45104 adv sample into dict.
# Extracted local importance feature of the 45105 adv sample into dict.
# Extracted local importance feature of the 45106 adv sample into dict.
# Extracted local importance feature of the 45107 adv sample into dict.
# Extracted local importance feature of the 45108 adv sample into dict.
# Extracted local importance feature of the 45109 adv sample into dict.
# Extracted local importance feature of the 45110 adv sample into dict.
# Extracted local importance feature of the 45111 adv sample into dict.
# Extracted local importance feature of the 45112 adv sample into dict.
# Extracted local importance feature of the 45113 adv sample into dict.
# Extracted local importance feature of the 45114 adv sample into dict.
# Extracted local importance feature of the 45115 adv sample into dict.
# Extracted local importance feature of the 45116 adv sample into dict.
# Extracted local importance feature of the 45117 adv sample into dict.
# Extracted local importance feature of the 45118 adv sample into dict.
# Extracted local importance feature of the 45119 adv sample into dict.
# Extracted local importance feature of the 45120 adv sample into dict.
# Extracted local importance feature of the 45121 adv sample into dict.
# Extracted local importance feature of the 45122 adv sample into dict.
# Extracted local importance feature of the 45123 adv sample into dict.
# Extracted local importance feature of the 45124 adv sample into dict.
# Extracted local importance feature of the 45125 adv sample into dict.
# Extracted local importance feature of the 45126 adv sample into dict.
# Extracted local importance feature of the 45127 adv sample into dict.
# Extracted local importance feature of the 45128 adv sample into dict.
# Extracted local importance feature of the 45129 adv sample into dict.
# Extracted local importance feature of the 45130 adv sample into dict.
# Extracted local importance feature of the 45131 adv sample into dict.
# Extracted local importance feature of the 45132 adv sample into dict.
# Extracted local importance feature of the 45133 adv sample into dict.
# Extracted local importance feature of the 45134 adv sample into dict.
# Extracted local importance feature of the 45135 adv sample into dict.
# Extracted local importance feature of the 45136 adv sample into dict.
# Extracted local importance feature of the 45137 adv sample into dict.
# Extracted local importance feature of the 45138 adv sample into dict.
# Extracted local importance feature of the 45139 adv sample into dict.
# Extracted local importance feature of the 45140 adv sample into dict.
# Extracted local importance feature of the 45141 adv sample into dict.
# Extracted local importance feature of the 45142 adv sample into dict.
# Extracted local importance feature of the 45143 adv sample into dict.
# Extracted local importance feature of the 45144 adv sample into dict.
# Extracted local importance feature of the 45145 adv sample into dict.
# Extracted local importance feature of the 45146 adv sample into dict.
# Extracted local importance feature of the 45147 adv sample into dict.
# Extracted local importance feature of the 45148 adv sample into dict.
# Extracted local importance feature of the 45149 adv sample into dict.
# Extracted local importance feature of the 45150 adv sample into dict.
# Extracted local importance feature of the 45151 adv sample into dict.
# Extracted local importance feature of the 45152 adv sample into dict.
# Extracted local importance feature of the 45153 adv sample into dict.
# Extracted local importance feature of the 45154 adv sample into dict.
# Extracted local importance feature of the 45155 adv sample into dict.
# Extracted local importance feature of the 45156 adv sample into dict.
# Extracted local importance feature of the 45157 adv sample into dict.
# Extracted local importance feature of the 45158 adv sample into dict.
# Extracted local importance feature of the 45159 adv sample into dict.
# Extracted local importance feature of the 45160 adv sample into dict.
# Extracted local importance feature of the 45161 adv sample into dict.
# Extracted local importance feature of the 45162 adv sample into dict.
# Extracted local importance feature of the 45163 adv sample into dict.
# Extracted local importance feature of the 45164 adv sample into dict.
# Extracted local importance feature of the 45165 adv sample into dict.
# Extracted local importance feature of the 45166 adv sample into dict.
# Extracted local importance feature of the 45167 adv sample into dict.
# Extracted local importance feature of the 45168 adv sample into dict.
# Extracted local importance feature of the 45169 adv sample into dict.
# Extracted local importance feature of the 45170 adv sample into dict.
# Extracted local importance feature of the 45171 adv sample into dict.
# Extracted local importance feature of the 45172 adv sample into dict.
# Extracted local importance feature of the 45173 adv sample into dict.
# Extracted local importance feature of the 45174 adv sample into dict.
# Extracted local importance feature of the 45175 adv sample into dict.
# Extracted local importance feature of the 45176 adv sample into dict.
# Extracted local importance feature of the 45177 adv sample into dict.
# Extracted local importance feature of the 45178 adv sample into dict.
# Extracted local importance feature of the 45179 adv sample into dict.
# Extracted local importance feature of the 45180 adv sample into dict.
# Extracted local importance feature of the 45181 adv sample into dict.
# Extracted local importance feature of the 45182 adv sample into dict.
# Extracted local importance feature of the 45183 adv sample into dict.
# Extracted local importance feature of the 45184 adv sample into dict.
# Extracted local importance feature of the 45185 adv sample into dict.
# Extracted local importance feature of the 45186 adv sample into dict.
# Extracted local importance feature of the 45187 adv sample into dict.
# Extracted local importance feature of the 45188 adv sample into dict.
# Extracted local importance feature of the 45189 adv sample into dict.
# Extracted local importance feature of the 45190 adv sample into dict.
# Extracted local importance feature of the 45191 adv sample into dict.
# Extracted local importance feature of the 45192 adv sample into dict.
# Extracted local importance feature of the 45193 adv sample into dict.
# Extracted local importance feature of the 45194 adv sample into dict.
# Extracted local importance feature of the 45195 adv sample into dict.
# Extracted local importance feature of the 45196 adv sample into dict.
# Extracted local importance feature of the 45197 adv sample into dict.
# Extracted local importance feature of the 45198 adv sample into dict.
# Extracted local importance feature of the 45199 adv sample into dict.
# Extracted local importance feature of the 45200 adv sample into dict.
# Extracted local importance feature of the 45201 adv sample into dict.
# Extracted local importance feature of the 45202 adv sample into dict.
# Extracted local importance feature of the 45203 adv sample into dict.
# Extracted local importance feature of the 45204 adv sample into dict.
# Extracted local importance feature of the 45205 adv sample into dict.
# Extracted local importance feature of the 45206 adv sample into dict.
# Extracted local importance feature of the 45207 adv sample into dict.
# Extracted local importance feature of the 45208 adv sample into dict.
# Extracted local importance feature of the 45209 adv sample into dict.
# Extracted local importance feature of the 45210 adv sample into dict.
# Extracted local importance feature of the 45211 adv sample into dict.
# Extracted local importance feature of the 45212 adv sample into dict.
# Extracted local importance feature of the 45213 adv sample into dict.
# Extracted local importance feature of the 45214 adv sample into dict.
# Extracted local importance feature of the 45215 adv sample into dict.
# Extracted local importance feature of the 45216 adv sample into dict.
# Extracted local importance feature of the 45217 adv sample into dict.
# Extracted local importance feature of the 45218 adv sample into dict.
# Extracted local importance feature of the 45219 adv sample into dict.
# Extracted local importance feature of the 45220 adv sample into dict.
# Extracted local importance feature of the 45221 adv sample into dict.
# Extracted local importance feature of the 45222 adv sample into dict.
# Extracted local importance feature of the 45223 adv sample into dict.
# Extracted local importance feature of the 45224 adv sample into dict.
# Extracted local importance feature of the 45225 adv sample into dict.
# Extracted local importance feature of the 45226 adv sample into dict.
# Extracted local importance feature of the 45227 adv sample into dict.
# Extracted local importance feature of the 45228 adv sample into dict.
# Extracted local importance feature of the 45229 adv sample into dict.
# Extracted local importance feature of the 45230 adv sample into dict.
# Extracted local importance feature of the 45231 adv sample into dict.
# Extracted local importance feature of the 45232 adv sample into dict.
# Extracted local importance feature of the 45233 adv sample into dict.
# Extracted local importance feature of the 45234 adv sample into dict.
# Extracted local importance feature of the 45235 adv sample into dict.
# Extracted local importance feature of the 45236 adv sample into dict.
# Extracted local importance feature of the 45237 adv sample into dict.
# Extracted local importance feature of the 45238 adv sample into dict.
# Extracted local importance feature of the 45239 adv sample into dict.
# Extracted local importance feature of the 45240 adv sample into dict.
# Extracted local importance feature of the 45241 adv sample into dict.
# Extracted local importance feature of the 45242 adv sample into dict.
# Extracted local importance feature of the 45243 adv sample into dict.
# Extracted local importance feature of the 45244 adv sample into dict.
# Extracted local importance feature of the 45245 adv sample into dict.
# Extracted local importance feature of the 45246 adv sample into dict.
# Extracted local importance feature of the 45247 adv sample into dict.
# Extracted local importance feature of the 45248 adv sample into dict.
# Extracted local importance feature of the 45249 adv sample into dict.
# Extracted local importance feature of the 45250 adv sample into dict.
# Extracted local importance feature of the 45251 adv sample into dict.
# Extracted local importance feature of the 45252 adv sample into dict.
# Extracted local importance feature of the 45253 adv sample into dict.
# Extracted local importance feature of the 45254 adv sample into dict.
# Extracted local importance feature of the 45255 adv sample into dict.
# Extracted local importance feature of the 45256 adv sample into dict.
# Extracted local importance feature of the 45257 adv sample into dict.
# Extracted local importance feature of the 45258 adv sample into dict.
# Extracted local importance feature of the 45259 adv sample into dict.
# Extracted local importance feature of the 45260 adv sample into dict.
# Extracted local importance feature of the 45261 adv sample into dict.
# Extracted local importance feature of the 45262 adv sample into dict.
# Extracted local importance feature of the 45263 adv sample into dict.
# Extracted local importance feature of the 45264 adv sample into dict.
# Extracted local importance feature of the 45265 adv sample into dict.
# Extracted local importance feature of the 45266 adv sample into dict.
# Extracted local importance feature of the 45267 adv sample into dict.
# Extracted local importance feature of the 45268 adv sample into dict.
# Extracted local importance feature of the 45269 adv sample into dict.
# Extracted local importance feature of the 45270 adv sample into dict.
# Extracted local importance feature of the 45271 adv sample into dict.
# Extracted local importance feature of the 45272 adv sample into dict.
# Extracted local importance feature of the 45273 adv sample into dict.
# Extracted local importance feature of the 45274 adv sample into dict.
# Extracted local importance feature of the 45275 adv sample into dict.
# Extracted local importance feature of the 45276 adv sample into dict.
# Extracted local importance feature of the 45277 adv sample into dict.
# Extracted local importance feature of the 45278 adv sample into dict.
# Extracted local importance feature of the 45279 adv sample into dict.
# Extracted local importance feature of the 45280 adv sample into dict.
# Extracted local importance feature of the 45281 adv sample into dict.
# Extracted local importance feature of the 45282 adv sample into dict.
# Extracted local importance feature of the 45283 adv sample into dict.
# Extracted local importance feature of the 45284 adv sample into dict.
# Extracted local importance feature of the 45285 adv sample into dict.
# Extracted local importance feature of the 45286 adv sample into dict.
# Extracted local importance feature of the 45287 adv sample into dict.
# Extracted local importance feature of the 45288 adv sample into dict.
# Extracted local importance feature of the 45289 adv sample into dict.
# Extracted local importance feature of the 45290 adv sample into dict.
# Extracted local importance feature of the 45291 adv sample into dict.
# Extracted local importance feature of the 45292 adv sample into dict.
# Extracted local importance feature of the 45293 adv sample into dict.
# Extracted local importance feature of the 45294 adv sample into dict.
# Extracted local importance feature of the 45295 adv sample into dict.
# Extracted local importance feature of the 45296 adv sample into dict.
# Extracted local importance feature of the 45297 adv sample into dict.
# Extracted local importance feature of the 45298 adv sample into dict.
# Extracted local importance feature of the 45299 adv sample into dict.
# Extracted local importance feature of the 45300 adv sample into dict.
# Extracted local importance feature of the 45301 adv sample into dict.
# Extracted local importance feature of the 45302 adv sample into dict.
# Extracted local importance feature of the 45303 adv sample into dict.
# Extracted local importance feature of the 45304 adv sample into dict.
# Extracted local importance feature of the 45305 adv sample into dict.
# Extracted local importance feature of the 45306 adv sample into dict.
# Extracted local importance feature of the 45307 adv sample into dict.
# Extracted local importance feature of the 45308 adv sample into dict.
# Extracted local importance feature of the 45309 adv sample into dict.
# Extracted local importance feature of the 45310 adv sample into dict.
# Extracted local importance feature of the 45311 adv sample into dict.
# Extracted local importance feature of the 45312 adv sample into dict.
# Extracted local importance feature of the 45313 adv sample into dict.
# Extracted local importance feature of the 45314 adv sample into dict.
# Extracted local importance feature of the 45315 adv sample into dict.
# Extracted local importance feature of the 45316 adv sample into dict.
# Extracted local importance feature of the 45317 adv sample into dict.
# Extracted local importance feature of the 45318 adv sample into dict.
# Extracted local importance feature of the 45319 adv sample into dict.
# Extracted local importance feature of the 45320 adv sample into dict.
# Extracted local importance feature of the 45321 adv sample into dict.
# Extracted local importance feature of the 45322 adv sample into dict.
# Extracted local importance feature of the 45323 adv sample into dict.
# Extracted local importance feature of the 45324 adv sample into dict.
# Extracted local importance feature of the 45325 adv sample into dict.
# Extracted local importance feature of the 45326 adv sample into dict.
# Extracted local importance feature of the 45327 adv sample into dict.
# Extracted local importance feature of the 45328 adv sample into dict.
# Extracted local importance feature of the 45329 adv sample into dict.
# Extracted local importance feature of the 45330 adv sample into dict.
# Extracted local importance feature of the 45331 adv sample into dict.
# Extracted local importance feature of the 45332 adv sample into dict.
# Extracted local importance feature of the 45333 adv sample into dict.
# Extracted local importance feature of the 45334 adv sample into dict.
# Extracted local importance feature of the 45335 adv sample into dict.
# Extracted local importance feature of the 45336 adv sample into dict.
# Extracted local importance feature of the 45337 adv sample into dict.
# Extracted local importance feature of the 45338 adv sample into dict.
# Extracted local importance feature of the 45339 adv sample into dict.
# Extracted local importance feature of the 45340 adv sample into dict.
# Extracted local importance feature of the 45341 adv sample into dict.
# Extracted local importance feature of the 45342 adv sample into dict.
# Extracted local importance feature of the 45343 adv sample into dict.
# Extracted local importance feature of the 45344 adv sample into dict.
# Extracted local importance feature of the 45345 adv sample into dict.
# Extracted local importance feature of the 45346 adv sample into dict.
# Extracted local importance feature of the 45347 adv sample into dict.
# Extracted local importance feature of the 45348 adv sample into dict.
# Extracted local importance feature of the 45349 adv sample into dict.
# Extracted local importance feature of the 45350 adv sample into dict.
# Extracted local importance feature of the 45351 adv sample into dict.
# Extracted local importance feature of the 45352 adv sample into dict.
# Extracted local importance feature of the 45353 adv sample into dict.
# Extracted local importance feature of the 45354 adv sample into dict.
# Extracted local importance feature of the 45355 adv sample into dict.
# Extracted local importance feature of the 45356 adv sample into dict.
# Extracted local importance feature of the 45357 adv sample into dict.
# Extracted local importance feature of the 45358 adv sample into dict.
# Extracted local importance feature of the 45359 adv sample into dict.
# Extracted local importance feature of the 45360 adv sample into dict.
# Extracted local importance feature of the 45361 adv sample into dict.
# Extracted local importance feature of the 45362 adv sample into dict.
# Extracted local importance feature of the 45363 adv sample into dict.
# Extracted local importance feature of the 45364 adv sample into dict.
# Extracted local importance feature of the 45365 adv sample into dict.
# Extracted local importance feature of the 45366 adv sample into dict.
# Extracted local importance feature of the 45367 adv sample into dict.
# Extracted local importance feature of the 45368 adv sample into dict.
# Extracted local importance feature of the 45369 adv sample into dict.
# Extracted local importance feature of the 45370 adv sample into dict.
# Extracted local importance feature of the 45371 adv sample into dict.
# Extracted local importance feature of the 45372 adv sample into dict.
# Extracted local importance feature of the 45373 adv sample into dict.
# Extracted local importance feature of the 45374 adv sample into dict.
# Extracted local importance feature of the 45375 adv sample into dict.
# Extracted local importance feature of the 45376 adv sample into dict.
# Extracted local importance feature of the 45377 adv sample into dict.
# Extracted local importance feature of the 45378 adv sample into dict.
# Extracted local importance feature of the 45379 adv sample into dict.
# Extracted local importance feature of the 45380 adv sample into dict.
# Extracted local importance feature of the 45381 adv sample into dict.
# Extracted local importance feature of the 45382 adv sample into dict.
# Extracted local importance feature of the 45383 adv sample into dict.
# Extracted local importance feature of the 45384 adv sample into dict.
# Extracted local importance feature of the 45385 adv sample into dict.
# Extracted local importance feature of the 45386 adv sample into dict.
# Extracted local importance feature of the 45387 adv sample into dict.
# Extracted local importance feature of the 45388 adv sample into dict.
# Extracted local importance feature of the 45389 adv sample into dict.
# Extracted local importance feature of the 45390 adv sample into dict.
# Extracted local importance feature of the 45391 adv sample into dict.
# Extracted local importance feature of the 45392 adv sample into dict.
# Extracted local importance feature of the 45393 adv sample into dict.
# Extracted local importance feature of the 45394 adv sample into dict.
# Extracted local importance feature of the 45395 adv sample into dict.
# Extracted local importance feature of the 45396 adv sample into dict.
# Extracted local importance feature of the 45397 adv sample into dict.
# Extracted local importance feature of the 45398 adv sample into dict.
# Extracted local importance feature of the 45399 adv sample into dict.
# Extracted local importance feature of the 45400 adv sample into dict.
# Extracted local importance feature of the 45401 adv sample into dict.
# Extracted local importance feature of the 45402 adv sample into dict.
# Extracted local importance feature of the 45403 adv sample into dict.
# Extracted local importance feature of the 45404 adv sample into dict.
# Extracted local importance feature of the 45405 adv sample into dict.
# Extracted local importance feature of the 45406 adv sample into dict.
# Extracted local importance feature of the 45407 adv sample into dict.
# Extracted local importance feature of the 45408 adv sample into dict.
# Extracted local importance feature of the 45409 adv sample into dict.
# Extracted local importance feature of the 45410 adv sample into dict.
# Extracted local importance feature of the 45411 adv sample into dict.
# Extracted local importance feature of the 45412 adv sample into dict.
# Extracted local importance feature of the 45413 adv sample into dict.
# Extracted local importance feature of the 45414 adv sample into dict.
# Extracted local importance feature of the 45415 adv sample into dict.
# Extracted local importance feature of the 45416 adv sample into dict.
# Extracted local importance feature of the 45417 adv sample into dict.
# Extracted local importance feature of the 45418 adv sample into dict.
# Extracted local importance feature of the 45419 adv sample into dict.
# Extracted local importance feature of the 45420 adv sample into dict.
# Extracted local importance feature of the 45421 adv sample into dict.
# Extracted local importance feature of the 45422 adv sample into dict.
# Extracted local importance feature of the 45423 adv sample into dict.
# Extracted local importance feature of the 45424 adv sample into dict.
# Extracted local importance feature of the 45425 adv sample into dict.
# Extracted local importance feature of the 45426 adv sample into dict.
# Extracted local importance feature of the 45427 adv sample into dict.
# Extracted local importance feature of the 45428 adv sample into dict.
# Extracted local importance feature of the 45429 adv sample into dict.
# Extracted local importance feature of the 45430 adv sample into dict.
# Extracted local importance feature of the 45431 adv sample into dict.
# Extracted local importance feature of the 45432 adv sample into dict.
# Extracted local importance feature of the 45433 adv sample into dict.
# Extracted local importance feature of the 45434 adv sample into dict.
# Extracted local importance feature of the 45435 adv sample into dict.
# Extracted local importance feature of the 45436 adv sample into dict.
# Extracted local importance feature of the 45437 adv sample into dict.
# Extracted local importance feature of the 45438 adv sample into dict.
# Extracted local importance feature of the 45439 adv sample into dict.
# Extracted local importance feature of the 45440 adv sample into dict.
# Extracted local importance feature of the 45441 adv sample into dict.
# Extracted local importance feature of the 45442 adv sample into dict.
# Extracted local importance feature of the 45443 adv sample into dict.
# Extracted local importance feature of the 45444 adv sample into dict.
# Extracted local importance feature of the 45445 adv sample into dict.
# Extracted local importance feature of the 45446 adv sample into dict.
# Extracted local importance feature of the 45447 adv sample into dict.
# Extracted local importance feature of the 45448 adv sample into dict.
# Extracted local importance feature of the 45449 adv sample into dict.
# Extracted local importance feature of the 45450 adv sample into dict.
# Extracted local importance feature of the 45451 adv sample into dict.
# Extracted local importance feature of the 45452 adv sample into dict.
# Extracted local importance feature of the 45453 adv sample into dict.
# Extracted local importance feature of the 45454 adv sample into dict.
# Extracted local importance feature of the 45455 adv sample into dict.
# Extracted local importance feature of the 45456 adv sample into dict.
# Extracted local importance feature of the 45457 adv sample into dict.
# Extracted local importance feature of the 45458 adv sample into dict.
# Extracted local importance feature of the 45459 adv sample into dict.
# Extracted local importance feature of the 45460 adv sample into dict.
# Extracted local importance feature of the 45461 adv sample into dict.
# Extracted local importance feature of the 45462 adv sample into dict.
# Extracted local importance feature of the 45463 adv sample into dict.
# Extracted local importance feature of the 45464 adv sample into dict.
# Extracted local importance feature of the 45465 adv sample into dict.
# Extracted local importance feature of the 45466 adv sample into dict.
# Extracted local importance feature of the 45467 adv sample into dict.
# Extracted local importance feature of the 45468 adv sample into dict.
# Extracted local importance feature of the 45469 adv sample into dict.
# Extracted local importance feature of the 45470 adv sample into dict.
# Extracted local importance feature of the 45471 adv sample into dict.
# Extracted local importance feature of the 45472 adv sample into dict.
# Extracted local importance feature of the 45473 adv sample into dict.
# Extracted local importance feature of the 45474 adv sample into dict.
# Extracted local importance feature of the 45475 adv sample into dict.
# Extracted local importance feature of the 45476 adv sample into dict.
# Extracted local importance feature of the 45477 adv sample into dict.
# Extracted local importance feature of the 45478 adv sample into dict.
# Extracted local importance feature of the 45479 adv sample into dict.
# Extracted local importance feature of the 45480 adv sample into dict.
# Extracted local importance feature of the 45481 adv sample into dict.
# Extracted local importance feature of the 45482 adv sample into dict.
# Extracted local importance feature of the 45483 adv sample into dict.
# Extracted local importance feature of the 45484 adv sample into dict.
# Extracted local importance feature of the 45485 adv sample into dict.
# Extracted local importance feature of the 45486 adv sample into dict.
# Extracted local importance feature of the 45487 adv sample into dict.
# Extracted local importance feature of the 45488 adv sample into dict.
# Extracted local importance feature of the 45489 adv sample into dict.
# Extracted local importance feature of the 45490 adv sample into dict.
# Extracted local importance feature of the 45491 adv sample into dict.
# Extracted local importance feature of the 45492 adv sample into dict.
# Extracted local importance feature of the 45493 adv sample into dict.
# Extracted local importance feature of the 45494 adv sample into dict.
# Extracted local importance feature of the 45495 adv sample into dict.
# Extracted local importance feature of the 45496 adv sample into dict.
# Extracted local importance feature of the 45497 adv sample into dict.
# Extracted local importance feature of the 45498 adv sample into dict.
# Extracted local importance feature of the 45499 adv sample into dict.
# Extracted local importance feature of the 45500 adv sample into dict.
# Extracted local importance feature of the 45501 adv sample into dict.
# Extracted local importance feature of the 45502 adv sample into dict.
# Extracted local importance feature of the 45503 adv sample into dict.
# Extracted local importance feature of the 45504 adv sample into dict.
# Extracted local importance feature of the 45505 adv sample into dict.
# Extracted local importance feature of the 45506 adv sample into dict.
# Extracted local importance feature of the 45507 adv sample into dict.
# Extracted local importance feature of the 45508 adv sample into dict.
# Extracted local importance feature of the 45509 adv sample into dict.
# Extracted local importance feature of the 45510 adv sample into dict.
# Extracted local importance feature of the 45511 adv sample into dict.
# Extracted local importance feature of the 45512 adv sample into dict.
# Extracted local importance feature of the 45513 adv sample into dict.
# Extracted local importance feature of the 45514 adv sample into dict.
# Extracted local importance feature of the 45515 adv sample into dict.
# Extracted local importance feature of the 45516 adv sample into dict.
# Extracted local importance feature of the 45517 adv sample into dict.
# Extracted local importance feature of the 45518 adv sample into dict.
# Extracted local importance feature of the 45519 adv sample into dict.
# Extracted local importance feature of the 45520 adv sample into dict.
# Extracted local importance feature of the 45521 adv sample into dict.
# Extracted local importance feature of the 45522 adv sample into dict.
# Extracted local importance feature of the 45523 adv sample into dict.
# Extracted local importance feature of the 45524 adv sample into dict.
# Extracted local importance feature of the 45525 adv sample into dict.
# Extracted local importance feature of the 45526 adv sample into dict.
# Extracted local importance feature of the 45527 adv sample into dict.
# Extracted local importance feature of the 45528 adv sample into dict.
# Extracted local importance feature of the 45529 adv sample into dict.
# Extracted local importance feature of the 45530 adv sample into dict.
# Extracted local importance feature of the 45531 adv sample into dict.
# Extracted local importance feature of the 45532 adv sample into dict.
# Extracted local importance feature of the 45533 adv sample into dict.
# Extracted local importance feature of the 45534 adv sample into dict.
# Extracted local importance feature of the 45535 adv sample into dict.
# Extracted local importance feature of the 45536 adv sample into dict.
# Extracted local importance feature of the 45537 adv sample into dict.
# Extracted local importance feature of the 45538 adv sample into dict.
# Extracted local importance feature of the 45539 adv sample into dict.
# Extracted local importance feature of the 45540 adv sample into dict.
# Extracted local importance feature of the 45541 adv sample into dict.
# Extracted local importance feature of the 45542 adv sample into dict.
# Extracted local importance feature of the 45543 adv sample into dict.
# Extracted local importance feature of the 45544 adv sample into dict.
# Extracted local importance feature of the 45545 adv sample into dict.
# Extracted local importance feature of the 45546 adv sample into dict.
# Extracted local importance feature of the 45547 adv sample into dict.
# Extracted local importance feature of the 45548 adv sample into dict.
# Extracted local importance feature of the 45549 adv sample into dict.
# Extracted local importance feature of the 45550 adv sample into dict.
# Extracted local importance feature of the 45551 adv sample into dict.
# Extracted local importance feature of the 45552 adv sample into dict.
# Extracted local importance feature of the 45553 adv sample into dict.
# Extracted local importance feature of the 45554 adv sample into dict.
# Extracted local importance feature of the 45555 adv sample into dict.
# Extracted local importance feature of the 45556 adv sample into dict.
# Extracted local importance feature of the 45557 adv sample into dict.
# Extracted local importance feature of the 45558 adv sample into dict.
# Extracted local importance feature of the 45559 adv sample into dict.
# Extracted local importance feature of the 45560 adv sample into dict.
# Extracted local importance feature of the 45561 adv sample into dict.
# Extracted local importance feature of the 45562 adv sample into dict.
# Extracted local importance feature of the 45563 adv sample into dict.
# Extracted local importance feature of the 45564 adv sample into dict.
# Extracted local importance feature of the 45565 adv sample into dict.
# Extracted local importance feature of the 45566 adv sample into dict.
# Extracted local importance feature of the 45567 adv sample into dict.
# Extracted local importance feature of the 45568 adv sample into dict.
# Extracted local importance feature of the 45569 adv sample into dict.
# Extracted local importance feature of the 45570 adv sample into dict.
# Extracted local importance feature of the 45571 adv sample into dict.
# Extracted local importance feature of the 45572 adv sample into dict.
# Extracted local importance feature of the 45573 adv sample into dict.
# Extracted local importance feature of the 45574 adv sample into dict.
# Extracted local importance feature of the 45575 adv sample into dict.
# Extracted local importance feature of the 45576 adv sample into dict.
# Extracted local importance feature of the 45577 adv sample into dict.
# Extracted local importance feature of the 45578 adv sample into dict.
# Extracted local importance feature of the 45579 adv sample into dict.
# Extracted local importance feature of the 45580 adv sample into dict.
# Extracted local importance feature of the 45581 adv sample into dict.
# Extracted local importance feature of the 45582 adv sample into dict.
# Extracted local importance feature of the 45583 adv sample into dict.
# Extracted local importance feature of the 45584 adv sample into dict.
# Extracted local importance feature of the 45585 adv sample into dict.
# Extracted local importance feature of the 45586 adv sample into dict.
# Extracted local importance feature of the 45587 adv sample into dict.
# Extracted local importance feature of the 45588 adv sample into dict.
# Extracted local importance feature of the 45589 adv sample into dict.
# Extracted local importance feature of the 45590 adv sample into dict.
# Extracted local importance feature of the 45591 adv sample into dict.
# Extracted local importance feature of the 45592 adv sample into dict.
# Extracted local importance feature of the 45593 adv sample into dict.
# Extracted local importance feature of the 45594 adv sample into dict.
# Extracted local importance feature of the 45595 adv sample into dict.
# Extracted local importance feature of the 45596 adv sample into dict.
# Extracted local importance feature of the 45597 adv sample into dict.
# Extracted local importance feature of the 45598 adv sample into dict.
# Extracted local importance feature of the 45599 adv sample into dict.
# Extracted local importance feature of the 45600 adv sample into dict.
# Extracted local importance feature of the 45601 adv sample into dict.
# Extracted local importance feature of the 45602 adv sample into dict.
# Extracted local importance feature of the 45603 adv sample into dict.
# Extracted local importance feature of the 45604 adv sample into dict.
# Extracted local importance feature of the 45605 adv sample into dict.
# Extracted local importance feature of the 45606 adv sample into dict.
# Extracted local importance feature of the 45607 adv sample into dict.
# Extracted local importance feature of the 45608 adv sample into dict.
# Extracted local importance feature of the 45609 adv sample into dict.
# Extracted local importance feature of the 45610 adv sample into dict.
# Extracted local importance feature of the 45611 adv sample into dict.
# Extracted local importance feature of the 45612 adv sample into dict.
# Extracted local importance feature of the 45613 adv sample into dict.
# Extracted local importance feature of the 45614 adv sample into dict.
# Extracted local importance feature of the 45615 adv sample into dict.
# Extracted local importance feature of the 45616 adv sample into dict.
# Extracted local importance feature of the 45617 adv sample into dict.
# Extracted local importance feature of the 45618 adv sample into dict.
# Extracted local importance feature of the 45619 adv sample into dict.
# Extracted local importance feature of the 45620 adv sample into dict.
# Extracted local importance feature of the 45621 adv sample into dict.
# Extracted local importance feature of the 45622 adv sample into dict.
# Extracted local importance feature of the 45623 adv sample into dict.
# Extracted local importance feature of the 45624 adv sample into dict.
# Extracted local importance feature of the 45625 adv sample into dict.
# Extracted local importance feature of the 45626 adv sample into dict.
# Extracted local importance feature of the 45627 adv sample into dict.
# Extracted local importance feature of the 45628 adv sample into dict.
# Extracted local importance feature of the 45629 adv sample into dict.
# Extracted local importance feature of the 45630 adv sample into dict.
# Extracted local importance feature of the 45631 adv sample into dict.
# Extracted local importance feature of the 45632 adv sample into dict.
# Extracted local importance feature of the 45633 adv sample into dict.
# Extracted local importance feature of the 45634 adv sample into dict.
# Extracted local importance feature of the 45635 adv sample into dict.
# Extracted local importance feature of the 45636 adv sample into dict.
# Extracted local importance feature of the 45637 adv sample into dict.
# Extracted local importance feature of the 45638 adv sample into dict.
# Extracted local importance feature of the 45639 adv sample into dict.
# Extracted local importance feature of the 45640 adv sample into dict.
# Extracted local importance feature of the 45641 adv sample into dict.
# Extracted local importance feature of the 45642 adv sample into dict.
# Extracted local importance feature of the 45643 adv sample into dict.
# Extracted local importance feature of the 45644 adv sample into dict.
# Extracted local importance feature of the 45645 adv sample into dict.
# Extracted local importance feature of the 45646 adv sample into dict.
# Extracted local importance feature of the 45647 adv sample into dict.
# Extracted local importance feature of the 45648 adv sample into dict.
# Extracted local importance feature of the 45649 adv sample into dict.
# Extracted local importance feature of the 45650 adv sample into dict.
# Extracted local importance feature of the 45651 adv sample into dict.
# Extracted local importance feature of the 45652 adv sample into dict.
# Extracted local importance feature of the 45653 adv sample into dict.
# Extracted local importance feature of the 45654 adv sample into dict.
# Extracted local importance feature of the 45655 adv sample into dict.
# Extracted local importance feature of the 45656 adv sample into dict.
# Extracted local importance feature of the 45657 adv sample into dict.
# Extracted local importance feature of the 45658 adv sample into dict.
# Extracted local importance feature of the 45659 adv sample into dict.
# Extracted local importance feature of the 45660 adv sample into dict.
# Extracted local importance feature of the 45661 adv sample into dict.
# Extracted local importance feature of the 45662 adv sample into dict.
# Extracted local importance feature of the 45663 adv sample into dict.
# Extracted local importance feature of the 45664 adv sample into dict.
# Extracted local importance feature of the 45665 adv sample into dict.
# Extracted local importance feature of the 45666 adv sample into dict.
# Extracted local importance feature of the 45667 adv sample into dict.
# Extracted local importance feature of the 45668 adv sample into dict.
# Extracted local importance feature of the 45669 adv sample into dict.
# Extracted local importance feature of the 45670 adv sample into dict.
# Extracted local importance feature of the 45671 adv sample into dict.
# Extracted local importance feature of the 45672 adv sample into dict.
# Extracted local importance feature of the 45673 adv sample into dict.
# Extracted local importance feature of the 45674 adv sample into dict.
# Extracted local importance feature of the 45675 adv sample into dict.
# Extracted local importance feature of the 45676 adv sample into dict.
# Extracted local importance feature of the 45677 adv sample into dict.
# Extracted local importance feature of the 45678 adv sample into dict.
# Extracted local importance feature of the 45679 adv sample into dict.
# Extracted local importance feature of the 45680 adv sample into dict.
# Extracted local importance feature of the 45681 adv sample into dict.
# Extracted local importance feature of the 45682 adv sample into dict.
# Extracted local importance feature of the 45683 adv sample into dict.
# ...
# Extracted local importance feature of the 49772 adv sample into dict.
# Extracted local importance feature of the 49773 adv sample into dict.
# Extracted local importance feature of the 49774 adv sample into dict.
# Extracted local importance feature of the 49775 adv sample into dict.
# Extracted local importance feature of the 49776 adv sample into dict.
# Extracted local importance feature of the 49777 adv sample into dict.
# Extracted local importance feature of the 49778 adv sample into dict.
# Extracted local importance feature of the 49779 adv sample into dict.
# Extracted local importance feature of the 49780 adv sample into dict.
# Extracted local importance feature of the 49781 adv sample into dict.
# Extracted local importance feature of the 49782 adv sample into dict.
# Extracted local importance feature of the 49783 adv sample into dict.
# Extracted local importance feature of the 49784 adv sample into dict.
# Extracted local importance feature of the 49785 adv sample into dict.
# Extracted local importance feature of the 49786 adv sample into dict.
# Extracted local importance feature of the 49787 adv sample into dict.
# Extracted local importance feature of the 49788 adv sample into dict.
# Extracted local importance feature of the 49789 adv sample into dict.
# Extracted local importance feature of the 49790 adv sample into dict.
# Extracted local importance feature of the 49791 adv sample into dict.
# Extracted local importance feature of the 49792 adv sample into dict.
# Extracted local importance feature of the 49793 adv sample into dict.
# Extracted local importance feature of the 49794 adv sample into dict.
# Extracted local importance feature of the 49795 adv sample into dict.
# Extracted local importance feature of the 49796 adv sample into dict.
# Extracted local importance feature of the 49797 adv sample into dict.
# Extracted local importance feature of the 49798 adv sample into dict.
# Extracted local importance feature of the 49799 adv sample into dict.
# Extracted local importance feature of the 49800 adv sample into dict.
# Extracted local importance feature of the 49801 adv sample into dict.
# Extracted local importance feature of the 49802 adv sample into dict.
# Extracted local importance feature of the 49803 adv sample into dict.
# Extracted local importance feature of the 49804 adv sample into dict.
# Extracted local importance feature of the 49805 adv sample into dict.
# Extracted local importance feature of the 49806 adv sample into dict.
# Extracted local importance feature of the 49807 adv sample into dict.
# Extracted local importance feature of the 49808 adv sample into dict.
# Extracted local importance feature of the 49809 adv sample into dict.
# Extracted local importance feature of the 49810 adv sample into dict.
# Extracted local importance feature of the 49811 adv sample into dict.
# Extracted local importance feature of the 49812 adv sample into dict.
# Extracted local importance feature of the 49813 adv sample into dict.
# Extracted local importance feature of the 49814 adv sample into dict.
# Extracted local importance feature of the 49815 adv sample into dict.
# Extracted local importance feature of the 49816 adv sample into dict.
# Extracted local importance feature of the 49817 adv sample into dict.
# Extracted local importance feature of the 49818 adv sample into dict.
# Extracted local importance feature of the 49819 adv sample into dict.
# Extracted local importance feature of the 49820 adv sample into dict.
# Extracted local importance feature of the 49821 adv sample into dict.
# Extracted local importance feature of the 49822 adv sample into dict.
# Extracted local importance feature of the 49823 adv sample into dict.
# Extracted local importance feature of the 49824 adv sample into dict.
# Extracted local importance feature of the 49825 adv sample into dict.
# Extracted local importance feature of the 49826 adv sample into dict.
# Extracted local importance feature of the 49827 adv sample into dict.
# Extracted local importance feature of the 49828 adv sample into dict.
# Extracted local importance feature of the 49829 adv sample into dict.
# Extracted local importance feature of the 49830 adv sample into dict.
# Extracted local importance feature of the 49831 adv sample into dict.
# Extracted local importance feature of the 49832 adv sample into dict.
# Extracted local importance feature of the 49833 adv sample into dict.
# Extracted local importance feature of the 49834 adv sample into dict.
# Extracted local importance feature of the 49835 adv sample into dict.
# Extracted local importance feature of the 49836 adv sample into dict.
# Extracted local importance feature of the 49837 adv sample into dict.
# Extracted local importance feature of the 49838 adv sample into dict.
# Extracted local importance feature of the 49839 adv sample into dict.
# Extracted local importance feature of the 49840 adv sample into dict.
# Extracted local importance feature of the 49841 adv sample into dict.
# Extracted local importance feature of the 49842 adv sample into dict.
# Extracted local importance feature of the 49843 adv sample into dict.
# Extracted local importance feature of the 49844 adv sample into dict.
# Extracted local importance feature of the 49845 adv sample into dict.
# Extracted local importance feature of the 49846 adv sample into dict.
# Extracted local importance feature of the 49847 adv sample into dict.
# Extracted local importance feature of the 49848 adv sample into dict.
# Extracted local importance feature of the 49849 adv sample into dict.
# Extracted local importance feature of the 49850 adv sample into dict.
# Extracted local importance feature of the 49851 adv sample into dict.
# Extracted local importance feature of the 49852 adv sample into dict.
# Extracted local importance feature of the 49853 adv sample into dict.
# Extracted local importance feature of the 49854 adv sample into dict.
# Extracted local importance feature of the 49855 adv sample into dict.
# Extracted local importance feature of the 49856 adv sample into dict.
# Extracted local importance feature of the 49857 adv sample into dict.
# Extracted local importance feature of the 49858 adv sample into dict.
# Extracted local importance feature of the 49859 adv sample into dict.
# Extracted local importance feature of the 49860 adv sample into dict.
# Extracted local importance feature of the 49861 adv sample into dict.
# Extracted local importance feature of the 49862 adv sample into dict.
# Extracted local importance feature of the 49863 adv sample into dict.
# Extracted local importance feature of the 49864 adv sample into dict.
# Extracted local importance feature of the 49865 adv sample into dict.
# Extracted local importance feature of the 49866 adv sample into dict.
# Extracted local importance feature of the 49867 adv sample into dict.
# Extracted local importance feature of the 49868 adv sample into dict.
# Extracted local importance feature of the 49869 adv sample into dict.
# Extracted local importance feature of the 49870 adv sample into dict.
# Extracted local importance feature of the 49871 adv sample into dict.
# Extracted local importance feature of the 49872 adv sample into dict.
# Extracted local importance feature of the 49873 adv sample into dict.
# Extracted local importance feature of the 49874 adv sample into dict.
# Extracted local importance feature of the 49875 adv sample into dict.
# Extracted local importance feature of the 49876 adv sample into dict.
# Extracted local importance feature of the 49877 adv sample into dict.
# Extracted local importance feature of the 49878 adv sample into dict.
# Extracted local importance feature of the 49879 adv sample into dict.
# Extracted local importance feature of the 49880 adv sample into dict.
# Extracted local importance feature of the 49881 adv sample into dict.
# Extracted local importance feature of the 49882 adv sample into dict.
# Extracted local importance feature of the 49883 adv sample into dict.
# Extracted local importance feature of the 49884 adv sample into dict.
# Extracted local importance feature of the 49885 adv sample into dict.
# Extracted local importance feature of the 49886 adv sample into dict.
# Extracted local importance feature of the 49887 adv sample into dict.
# Extracted local importance feature of the 49888 adv sample into dict.
# Extracted local importance feature of the 49889 adv sample into dict.
# Extracted local importance feature of the 49890 adv sample into dict.
# Extracted local importance feature of the 49891 adv sample into dict.
# Extracted local importance feature of the 49892 adv sample into dict.
# Extracted local importance feature of the 49893 adv sample into dict.
# Extracted local importance feature of the 49894 adv sample into dict.
# Extracted local importance feature of the 49895 adv sample into dict.
# Extracted local importance feature of the 49896 adv sample into dict.
# Extracted local importance feature of the 49897 adv sample into dict.
# Extracted local importance feature of the 49898 adv sample into dict.
# Extracted local importance feature of the 49899 adv sample into dict.
# Extracted local importance feature of the 49900 adv sample into dict.
# Extracted local importance feature of the 49901 adv sample into dict.
# Extracted local importance feature of the 49902 adv sample into dict.
# Extracted local importance feature of the 49903 adv sample into dict.
# Extracted local importance feature of the 49904 adv sample into dict.
# Extracted local importance feature of the 49905 adv sample into dict.
# Extracted local importance feature of the 49906 adv sample into dict.
# Extracted local importance feature of the 49907 adv sample into dict.
# Extracted local importance feature of the 49908 adv sample into dict.
# Extracted local importance feature of the 49909 adv sample into dict.
# Extracted local importance feature of the 49910 adv sample into dict.
# Extracted local importance feature of the 49911 adv sample into dict.
# Extracted local importance feature of the 49912 adv sample into dict.
# Extracted local importance feature of the 49913 adv sample into dict.
# Extracted local importance feature of the 49914 adv sample into dict.
# Extracted local importance feature of the 49915 adv sample into dict.
# Extracted local importance feature of the 49916 adv sample into dict.
# Extracted local importance feature of the 49917 adv sample into dict.
# Extracted local importance feature of the 49918 adv sample into dict.
# Extracted local importance feature of the 49919 adv sample into dict.
# Extracted local importance feature of the 49920 adv sample into dict.
# Extracted local importance feature of the 49921 adv sample into dict.
# Extracted local importance feature of the 49922 adv sample into dict.
# Extracted local importance feature of the 49923 adv sample into dict.
# Extracted local importance feature of the 49924 adv sample into dict.
# Extracted local importance feature of the 49925 adv sample into dict.
# Extracted local importance feature of the 49926 adv sample into dict.
# Extracted local importance feature of the 49927 adv sample into dict.
# Extracted local importance feature of the 49928 adv sample into dict.
# Extracted local importance feature of the 49929 adv sample into dict.
# Extracted local importance feature of the 49930 adv sample into dict.
# Extracted local importance feature of the 49931 adv sample into dict.
# Extracted local importance feature of the 49932 adv sample into dict.
# Extracted local importance feature of the 49933 adv sample into dict.
# Extracted local importance feature of the 49934 adv sample into dict.
# Extracted local importance feature of the 49935 adv sample into dict.
# Extracted local importance feature of the 49936 adv sample into dict.
# Extracted local importance feature of the 49937 adv sample into dict.
# Extracted local importance feature of the 49938 adv sample into dict.
# Extracted local importance feature of the 49939 adv sample into dict.
# Extracted local importance feature of the 49940 adv sample into dict.
# Extracted local importance feature of the 49941 adv sample into dict.
# Extracted local importance feature of the 49942 adv sample into dict.
# Extracted local importance feature of the 49943 adv sample into dict.
# Extracted local importance feature of the 49944 adv sample into dict.
# Extracted local importance feature of the 49945 adv sample into dict.
# Extracted local importance feature of the 49946 adv sample into dict.
# Extracted local importance feature of the 49947 adv sample into dict.
# Extracted local importance feature of the 49948 adv sample into dict.
# Extracted local importance feature of the 49949 adv sample into dict.
# Extracted local importance feature of the 49950 adv sample into dict.
# Extracted local importance feature of the 49951 adv sample into dict.
# Extracted local importance feature of the 49952 adv sample into dict.
# Extracted local importance feature of the 49953 adv sample into dict.
# Extracted local importance feature of the 49954 adv sample into dict.
# Extracted local importance feature of the 49955 adv sample into dict.
# Extracted local importance feature of the 49956 adv sample into dict.
# Extracted local importance feature of the 49957 adv sample into dict.
# Extracted local importance feature of the 49958 adv sample into dict.
# Extracted local importance feature of the 49959 adv sample into dict.
# Extracted local importance feature of the 49960 adv sample into dict.
# Extracted local importance feature of the 49961 adv sample into dict.
# Extracted local importance feature of the 49962 adv sample into dict.
# Extracted local importance feature of the 49963 adv sample into dict.
# Extracted local importance feature of the 49964 adv sample into dict.
# Extracted local importance feature of the 49965 adv sample into dict.
# Extracted local importance feature of the 49966 adv sample into dict.
# Extracted local importance feature of the 49967 adv sample into dict.
# Extracted local importance feature of the 49968 adv sample into dict.
# Extracted local importance feature of the 49969 adv sample into dict.
# Extracted local importance feature of the 49970 adv sample into dict.
# Extracted local importance feature of the 49971 adv sample into dict.
# Extracted local importance feature of the 49972 adv sample into dict.
# Extracted local importance feature of the 49973 adv sample into dict.
# Extracted local importance feature of the 49974 adv sample into dict.
# Extracted local importance feature of the 49975 adv sample into dict.
# Extracted local importance feature of the 49976 adv sample into dict.
# Extracted local importance feature of the 49977 adv sample into dict.
# Extracted local importance feature of the 49978 adv sample into dict.
# Extracted local importance feature of the 49979 adv sample into dict.
# Extracted local importance feature of the 49980 adv sample into dict.
# Extracted local importance feature of the 49981 adv sample into dict.
# Extracted local importance feature of the 49982 adv sample into dict.
# Extracted local importance feature of the 49983 adv sample into dict.
# Extracted local importance feature of the 49984 adv sample into dict.
# Extracted local importance feature of the 49985 adv sample into dict.
# Extracted local importance feature of the 49986 adv sample into dict.
# Extracted local importance feature of the 49987 adv sample into dict.
# Extracted local importance feature of the 49988 adv sample into dict.
# Extracted local importance feature of the 49989 adv sample into dict.
# Extracted local importance feature of the 49990 adv sample into dict.
# Extracted local importance feature of the 49991 adv sample into dict.
# Extracted local importance feature of the 49992 adv sample into dict.
# Extracted local importance feature of the 49993 adv sample into dict.
# Extracted local importance feature of the 49994 adv sample into dict.
# Extracted local importance feature of the 49995 adv sample into dict.
# Extracted local importance feature of the 49996 adv sample into dict.
# Extracted local importance feature of the 49997 adv sample into dict.
# Extracted local importance feature of the 49998 adv sample into dict.
# Extracted local importance feature of the 49999 adv sample into dict.

# %%
# Print an item of data dictionary
for file_name, data_list in data_dict.items():
    print(file_name, ":", data_list)
    break
# Out:
# SHAP_ADVSamples_0 : ['Bwd Pkt Len Min', 'Pkt Len Std', 'Pkt Size Avg', 'Fwd Pkt Len Max', 'Pkt Len Max', 'Down/Up Ratio', 'Bwd Seg Size Avg', 'Pkt Len Mean', 'Tot Fwd Pkts', 'Bwd Pkt Len Mean']

# %%
alert = []

# Iterate over each key-value pair in the data_dict
for key, value in data_dict.items():
    # Check if there are one feature is not in the whitelist
    for string in value:
      if string not in whitelist:
        alert.append(key)
        break

# Print the alert dictionary
print("Alert list length:" + str(len(alert)))
# Out:
# Alert list length:30674

# %% [markdown]
# ##Detection rate (top 38) = 29667/50000

# %%
whitelist2 = whitelist_df.iloc[:, 0][:38].tolist()
print(whitelist2)
# Out:
# ['Bwd Header Len', 'Pkt Size Avg', 'Pkt Len Max', 'Fwd Header Len', 'Pkt Len Std', 'Pkt Len Mean', 'Bwd Pkt Len Min', 'Pkt Len Min', 'Bwd Seg Size Avg', 'Down/Up Ratio', 'Init Bwd Win Byts', 'Fwd Seg Size Avg', 'Bwd Pkts/s', 'Subflow Bwd Pkts', 'Flow Pkts/s', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'SYN Flag Cnt', 'FIN Flag Cnt', 'ACK Flag Cnt', 'Bwd Pkt Len Max', 'Fwd Pkt Len Max', 'Tot Bwd Pkts', 'Fwd Pkt Len Min', 'Bwd Pkt Len Mean', 'Bwd IAT Mean', 'Fwd Pkt Len Mean', 'Init Fwd Win Byts', 'Fwd Pkts/s', 'Flow IAT Min', 'Bwd PSH Flags', 'Bwd IAT Max', 'Bwd IAT Min', 'PSH Flag Cnt', 'Flow IAT Std', 'Flow Duration', 'Flow IAT Max', 'Bwd Pkt Len Std']

# %%
alert2 = []

# Iterate over each key-value pair in the data_dict
for key, value in data_dict.items():
    # Check if there are one feature is not in the whitelist
    for string in value:
      if string not in whitelist2:
        alert2.append(key)
        break

# Print the alert dictionary
print("Alert list length:" + str(len(alert2)))
# Out:
# Alert list length:6961
